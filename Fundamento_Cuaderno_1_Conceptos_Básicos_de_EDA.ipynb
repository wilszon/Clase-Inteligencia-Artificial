# %% [markdown]
# <a href="https://colab.research.google.com/github/wilszon/Clase-Inteligencia-Artificial/blob/main/Fundamento_Cuaderno_1_Conceptos_B%C3%A1sicos_de_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="red">Cuaderno 1: Conceptos Básicos de EDA <p>
#
# El análisis exploratorio de datos (EDA, por sus siglas en inglés) es un proceso crucial en el análisis de datos, ya que permite identificar las características principales de un conjunto de datos, visualizar patrones y realizar análisis estadísticos para una mejor comprensión. En este Sesion se cubren los conceptos básicos de EDA, incluyendo tipos de datos, visualización, medidas estadísticas y análisis de distribuciones.

# %% [markdown]
# ## <font color="red">1.1 Identificación de tipos de datos <p>
#
# ![imagen](https://static.platzi.com/media/user_upload/Variables-e57fc8fe-6eb3-43e1-bf18-3362f3ed9da8.jpg)
#
# En la grafica anterior se muestra como se clasifican los tipos de variables tanto cualitativa y cuantitativamente y como se pueden utilizar en los modelos de prediccion.
#
# Ademas vamos a detallar como los datos se pueden clasificar en varias categorías según su naturaleza:
#
#
# *   **Numéricos:** Representan valores cuantitativos.
#
# Subcategorías:
#
# **Continuos:** Pueden tomar cualquier valor en un rango (ej. altura, peso).
#
# **Discretos:** Toman valores específicos (ej. número de hijos).
#
#
# - **Categóricos nominales:**
# Representan grupos o categorías. Ejemplo: género, color de ojos.
#
# - **Categóricos Ordinales:**
# Son categóricos, pero tienen un orden o jerarquía. Ejemplo: niveles de educación (primaria, secundaria, superior).
#
#
#
#
# ---
#
# # <font color="red">1.2 Visualización de datos y sus patrones <p>
# La visualización es fundamental en el EDA para detectar patrones, anomalías y relaciones entre variables. Algunas técnicas comunes incluyen:
#
#
#
# * Histogramas: Útiles para visualizar la distribución de una variable numérica.
# *   Gráficos de dispersión (scatter plots): Muestran relaciones entre dos variables numéricas.
# * Diagramas de caja (boxplots): Ayudan a identificar valores atípicos y medir la dispersión de datos.
#
#
#
# ---
# # <font color="red">1.3 Descripción estadística <p>
# El análisis descriptivo resume las principales características de los datos mediante estadísticas fundamentales:
#
# ## <font color="blue">1.3.1 Medidas de tendencia central
# * Media: Promedio de los datos
# * Mediana: Valor central al ordenar los datos.
# * Moda: Valor más frecuente en los datos.
#
# ## <font color="blue">1.3.2 Medidas de dispersión
#
# * Varianza: Mide la variabilidad de los datos.
# * Desviación estándar: Raíz cuadrada de la varianza, indica qué tan dispersos están los datos respecto a la media.
# * Rango: Diferencia entre el valor máximo y mínimo.
#
#
#
#
# ---
# # <font color="red">1.4 Análisis de distribuciones de datos <p>
# ## <font color="blue">1.4.1 Asimetría
# Mide la simetría de la distribución.
# * Asimetría positiva: Cola más larga a la derecha.
# * Asimetría negativa: Cola más larga a la izquierda.
#
# ## <font color="blue">1.4.2 Curtosis:
# Mide qué tan apuntada o plana es la distribución.
# * Curtosis alta: Distribución con colas más pesadas (picos altos).
# * Curtosis baja: Distribución más plana.
#
#
# ---
#
# # <font color="red">1.5 Ejemplo Práctico con Python
#
# Vamos a analizar un pequeño dataset simulado usando Pandas, Seaborn, Matplotlib y otras herramientas. El dataset incluye datos de calificaciones de estudiantes, género y edad.
#
# # <font color="blue">1.5.1 Dataset

# %%
import pandas as pd
import numpy as np

# Crear un dataset simulado
np.random.seed(42)
data = {
    "Estudiante": [f"E{i}" for i in range(1, 21)],
    "Edad": np.random.randint(18, 25, size=20),
    "Género": np.random.choice(["Femenino", "Masculino"], size=20),
    "Nota_Matemáticas": np.random.normal(70, 10, size=20).round(1),
    "Nota_Ciencias": np.random.normal(75, 12, size=20).round(1),
    "Nota_Inglés": np.random.normal(65, 15, size=20).round(1),
}
data
# Out:
# {'Estudiante': ['E1',
#   'E2',
#   'E3',
#   'E4',
#   'E5',
#   'E6',
#   'E7',
#   'E8',
#   'E9',
#   'E10',
#   'E11',
#   'E12',
#   'E13',
#   'E14',
#   'E15',
#   'E16',
#   'E17',
#   'E18',
#   'E19',
#   'E20'],
#  'Edad': array([24, 21, 22, 24, 20, 22, 22, 24, 19, 20, 24, 20, 20, 22, 21, 20, 23,
#         22, 19, 21]),
#  'Género': array(['Masculino', 'Masculino', 'Masculino', 'Masculino', 'Masculino',
#         'Femenino', 'Femenino', 'Masculino', 'Masculino', 'Masculino',
#         'Femenino', 'Masculino', 'Femenino', 'Femenino', 'Femenino',
#         'Femenino', 'Femenino', 'Masculino', 'Masculino', 'Masculino'],
#        dtype='<U9'),
#  'Nota_Matemáticas': array([72.2, 62.3, 71.4, 69.7, 81.3, 69. , 64.7, 89.1, 49.7, 81.2, 77.8,
#         59. , 81.3, 73.7, 66.1, 58.4, 75.7, 63. , 56.2, 66.5]),
#  'Nota_Ciencias': array([ 69.5,  75.8,  72.9,  89.4,  83.4,  72.9,  64.1,  89.3,  84.4,
#         106.9,  78.2,  94.7,  80.5,  76. ,  56.9,  83.7,  64.9,  68.8,
# ...

# %%
clientes=pd.read_csv("https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/Churn_Modelling.csv")
clientes.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          1    15634602  Hargrave          619    France  Female  42.0
# 2          2    15647311      Hill          608     Spain     NaN  41.0
# 3          3    15619304      Onio          502    France  Female  42.0
# 4          4    15701354      Boni          699    France  Female  39.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       2       0.00              1          1               1
# 2       1   83807.86             25          0               1
# 3       8  159660.80              3          1               0
# 4       1       0.00              2          0               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        101348.88       1
# 2        112542.58       0
# 3        113931.57       1
# ...

# %%
clientes.shape
# Out:
# (10002, 14)

# %%
clientes.drop(["RowNumber",'CustomerId', 'Surname'],axis=1,inplace=True)
#clientes=clientes.drop(["RowNumber",'CustomerId', 'Surname'],axis=1)

# %%
clientes.head()
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.0       2       0.00              1
# 1          619    France  Female  42.0       2       0.00              1
# 2          608     Spain     NaN  41.0       1   83807.86             25
# 3          502    France  Female  42.0       8  159660.80              3
# 4          699    France  Female  39.0       1       0.00              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          1               1        101348.88       1
# 2          0               1        112542.58       0
# 3          1               0        113931.57       1
# 4          0               0         93826.63       0

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)

# Mostrar el dataset
df.head()
# Out:
#   Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 0         E1    24  Masculino              72.2           69.5         41.6
# 1         E2    21  Masculino              62.3           75.8         53.1
# 2         E3    22  Masculino              71.4           72.9         79.0
# 3         E4    24  Masculino              69.7           89.4         75.2
# 4         E5    20  Masculino              81.3           83.4         75.5

# %%
df.tail(3)
# Out:
#    Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 17        E18    22  Masculino              63.0           68.8         81.0
# 18        E19    19  Masculino              56.2           74.5         51.0
# 19        E20    21  Masculino              66.5           71.7         76.8

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Estudiante           object
# Edad                  int64
# Género               object
# Nota_Matemáticas    float64
# Nota_Ciencias       float64
# Nota_Inglés         float64
# dtype: object

# %%
#cambiar el campo Estudiantes a string
df["Estudiante"] = df["Estudiante"].astype(str)
df.dtypes
# Out:
# Estudiante           object
# Edad                  int64
# Género               object
# Nota_Matemáticas    float64
# Nota_Ciencias       float64
# Nota_Inglés         float64
# dtype: object

# %% [markdown]
# # <font color="red">1.6 Script para EDA
#
# ## <font color="blue">1.6.1 Describir los datos

# %%
# Descripción estadística
print("Descripción estadística:")
print(df.describe())
# Out:
# Descripción estadística:
#             Edad  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# count  20.000000          20.00000      20.000000    20.000000
# mean   21.500000          69.41500      77.925000    66.055000
# std     1.670172           9.93565      11.608204    15.406269
# min    19.000000          49.70000      56.900000    34.300000
# 25%    20.000000          62.82500      71.150000    53.400000
# 50%    21.500000          69.35000      75.900000    71.600000
# 75%    22.250000          76.22500      83.875000    77.350000
# max    24.000000          89.10000     106.900000    83.500000

# %%
df.describe(include="object")
# Out:
#        Estudiante     Género
# count          20         20
# unique         20          2
# top            E1  Masculino
# freq            1         12

# %%
#sacar el porcentage de género
from matplotlib import pyplot as plt
cantidad=df.Género.value_counts(normalize=True)
plt.bar(cantidad.index, cantidad.values)
#df["Género"].value_counts()
# Out:
# <BarContainer object of 2 artists>

# %%
contarGenero=df.Género.value_counts()
total=contarGenero.values.sum()
total
# Out:
# np.int64(20)

# %%
print(contarGenero['Masculino'])
print(contarGenero['Femenino'])
# Out:
# 12
# 8

# %%
print("% de Hombres", contarGenero['Masculino']/total*100)
print("% de Mujeres", contarGenero['Femenino']/total*100)
# Out:
# % de Hombres 60.0
# % de Mujeres 40.0

# %%
from enum import auto
contarGenero.plot(kind="pie",autopct="%1.1f%%", colors=["lightgreen", "aqua"], startangle=0)
# Out:
# <Axes: ylabel='count'>

# %%
df.Género.unique()
# Out:
# array(['Masculino', 'Femenino'], dtype=object)

# %%
df.Género.nunique()
# Out:
# 2

# %%
desvEdad=df.describe(include="integer").T["std"]["Edad"]

# %%
desvEdad
# Out:
# np.float64(1.670171752907624)

# %%
df.Nota_Ciencias.median()
# Out:
# 75.9

# %%
df.Nota_Ciencias.std()
# Out:
# 11.608203768750881

# %% [markdown]
# ## <font color="blue">1.6.2 Visualizaciones

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histograma de edades
sns.histplot(df['Edad'], bins=4, kde=True, color='aqua')
plt.title("Distribución de Edad")
plt.show()

# Gráfico de dispersión: Nota_Matemáticas vs Nota_Ciencias
sns.scatterplot(x="Nota_Matemáticas", y="Nota_Ciencias", hue="Género", data=df)
plt.title("Relación entre Matemáticas y Ciencias")
plt.show()

# Boxplot de notas por género
sns.boxplot(x="Género", y="Nota_Matemáticas", data=df)
plt.title("Distribución de Notas de Matemáticas por Género")
plt.show()

# %%
df['Nota_Matemáticas'].describe()
# Out:
# count    20.00000
# mean     69.41500
# std       9.93565
# min      49.70000
# 25%      62.82500
# 50%      69.35000
# 75%      76.22500
# max      89.10000
# Name: Nota_Matemáticas, dtype: float64

# %% [markdown]
# ## <font color="blue">1.6.3 Análisis de distribución

# %% [markdown]
# ## <font color="blue">1.6.4 Resultados esperados
#
# * Descripción estadística: Resumen de tendencias centrales y dispersión.
# * Histogramas: Visualización clara de distribuciones de edad y notas.
# * Gráficos de dispersión: Identificación de relaciones entre materias y posibles patrones.
# * Boxplots: Análisis de diferencias en las distribuciones de notas por género.
# * Asimetría y curtosis: Indicadores clave de la forma de la distribución de las notas.
#
#
# Este ejemplo sirve como base para retos en otros temas, como la selección de características relevantes o la implementación de algoritmos predictivos.

# %% [markdown]
# ## <font color="blue">1.6.5 Dataset
# Utilizaremos el mismo dataset simulado previamente, pero expandiremos los análisis y visualizaciones.

# %%
import pandas as pd
import numpy as np

# Crear un dataset simulado
np.random.seed(42)
data = {
    "Estudiante": [f"E{i}" for i in range(1, 21)],
    "Edad": np.random.randint(18, 25, size=20),
    "Género": np.random.choice(["Femenino", "Masculino"], size=20),
    "Nota_Matemáticas": np.random.normal(70, 10, size=20).round(1),
    "Nota_Ciencias": np.random.normal(75, 12, size=20).round(1),
    "Nota_Inglés": np.random.normal(65, 15, size=20).round(1),
}
df = pd.DataFrame(data)
df
# Out:
#    Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 0          E1    24  Masculino              72.2           69.5         41.6
# 1          E2    21  Masculino              62.3           75.8         53.1
# 2          E3    22  Masculino              71.4           72.9         79.0
# 3          E4    24  Masculino              69.7           89.4         75.2
# 4          E5    20  Masculino              81.3           83.4         75.5
# 5          E6    22   Femenino              69.0           72.9         67.6
# 6          E7    22   Femenino              64.7           64.1         74.9
# 7          E8    24  Masculino              89.1           89.3         68.6
# 8          E9    19  Masculino              49.7           84.4         62.5
# 9         E10    20  Masculino              81.2          106.9         82.5
# 10        E11    24   Femenino              77.8           78.2         61.3
# ...

# %% [markdown]
# ## <font color="red">1.7 Ejemplo con value_counts y gráficos
# Análisis de la variable categórica "Género":

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Conteo de valores únicos en la columna "Género"
genero_counts = df["Género"].value_counts()

print("Conteo de valores por género:")
print(genero_counts)

# Gráfico de barras para visualizar el conteo de género
sns.barplot(x=genero_counts.index, y=genero_counts.values, palette="pastel")
plt.title("Distribución por Género")
plt.xlabel("Género")
plt.ylabel("Conteo")
plt.show()
# Out:
# Conteo de valores por género:
# Género
# Masculino    12
# Femenino      8
# Name: count, dtype: int64
# <ipython-input-28-1867d90d4fbc>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genero_counts.index, y=genero_counts.values, palette="pastel")

# %%
sns.countplot(x = df.Género, hue = df.Género)
# Out:
# <Axes: xlabel='Género', ylabel='count'>

# %% [markdown]
# # <font color="red">1.8 Ejemplo con unique y nunique
# Encontrar valores únicos y su cantidad:

# %%
# Valores únicos de "Edad"
valores_unicos_edad = df["Edad"].unique()
cantidad_unica_edad = df["Edad"].nunique()

print(f"Valores únicos en 'Edad': {valores_unicos_edad}")
print(f"Cantidad de valores únicos en 'Edad': {cantidad_unica_edad}")
# Out:
# Valores únicos en 'Edad': [24 21 22 20 19 23]
# Cantidad de valores únicos en 'Edad': 6

# %%
df.columns
# Out:
# Index(['Estudiante', 'Edad', 'Género', 'Nota_Matemáticas', 'Nota_Ciencias',
#        'Nota_Inglés'],
#       dtype='object')

# %%
df[df["Edad"]<23].iloc[:,-3:]
# Out:
#     Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 1               62.3           75.8         53.1
# 2               71.4           72.9         79.0
# 4               81.3           83.4         75.5
# 5               69.0           72.9         67.6
# 6               64.7           64.1         74.9
# 8               49.7           84.4         62.5
# 9               81.2          106.9         82.5
# 11              59.0           94.7         53.5
# 12              81.3           80.5         83.2
# 13              73.7           76.0         83.5
# 14              66.1           56.9         41.4
# 15              58.4           83.7         74.6
# 17              63.0           68.8         81.0
# 18              56.2           74.5         51.0
# 19              66.5           71.7         76.8

# %% [markdown]
# ## <font color="blue">1.8.1 Gráfico de barras para edades únicas:

# %%
# Conteo de edades
edad_counts = df["Edad"].value_counts()

edad_counts
# Out:
# Edad
# 20    5
# 22    5
# 24    4
# 21    3
# 19    2
# 23    1
# Name: count, dtype: int64

# %%
sns.barplot(x=edad_counts.index, y=edad_counts.values, hue=edad_counts.index)
plt.title("Frecuencia de Edades")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# # <font color="red">1.9 Ejemplo con describe
# Resumen estadístico de las variables numéricas:

# %%
descripcion = df.describe()

print("Resumen estadístico:")
print(descripcion)
# Out:
# Resumen estadístico:
#             Edad  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# count  20.000000          20.00000      20.000000    20.000000
# mean   21.500000          69.41500      77.925000    66.055000
# std     1.670172           9.93565      11.608204    15.406269
# min    19.000000          49.70000      56.900000    34.300000
# 25%    20.000000          62.82500      71.150000    53.400000
# 50%    21.500000          69.35000      75.900000    71.600000
# 75%    22.250000          76.22500      83.875000    77.350000
# max    24.000000          89.10000     106.900000    83.500000

# %% [markdown]
# ## <font color="blue">1.9.1 Gráfico de boxplots para resumir las notas:

# %%
# Crear boxplots para las tres asignaturas
sns.boxplot(data=df[["Nota_Matemáticas", "Nota_Ciencias", "Nota_Inglés"]], palette="coolwarm")
plt.title("Resumen de Notas")
plt.xlabel("Asignaturas")
plt.ylabel("Calificaciones")
plt.show()

# %%
df[df['Nota_Ciencias']>100]
# Out:
#   Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 9        E10    20  Masculino              81.2          106.9         82.5

# %%
# prompt: modificar el valor del estudiante de la fila 9, es E10, y la nota_ciencias es 100

# Access the DataFrame (assuming 'df' is already defined as in your example)
df.loc[df.index[9], 'Nota_Ciencias'] = 100

# Verify the change
df.iloc[9]
# Out:
# Estudiante                E10
# Edad                       20
# Género              Masculino
# Nota_Matemáticas         81.2
# Nota_Ciencias           100.0
# Nota_Inglés              82.5
# Name: 9, dtype: object

# %% [markdown]
# # <font color="red">1.10 Ejemplo con info

# %%
print("Información del dataset:")
print(df.info())
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Estudiante        20 non-null     object
#  1   Edad              20 non-null     int64
#  2   Género            20 non-null     object
#  3   Nota_Matemáticas  20 non-null     float64
#  4   Nota_Ciencias     20 non-null     float64
#  5   Nota_Inglés       20 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.1+ KB
# None

# %% [markdown]
# # <font color="red">1.11 Ejemplo con isnull
# Verificación de valores nulos:

# %%
df.loc[df.index[4], 'Nota_Ciencias'] = np.nan

# %%
df.head()
# Out:
#   Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 0         E1    24  Masculino              72.2           69.5         41.6
# 1         E2    21  Masculino              62.3           75.8         53.1
# 2         E3    22  Masculino              71.4           72.9         79.0
# 3         E4    24  Masculino              69.7           89.4         75.2
# 4         E5    20  Masculino              81.3            NaN         75.5

# %%
df.isnull()
# Out:
#     Estudiante   Edad  Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 0        False  False   False             False          False        False
# 1        False  False   False             False          False        False
# 2        False  False   False             False          False        False
# 3        False  False   False             False          False        False
# 4        False  False   False             False           True        False
# 5        False  False   False             False          False        False
# 6        False  False   False             False          False        False
# 7        False  False   False             False          False        False
# 8        False  False   False             False          False        False
# 9        False  False   False             False          False        False
# 10       False  False   False             False          False        False
# ...

# %%
valores_nulos = df.isnull().sum()

print("Valores nulos por columna:")
print(valores_nulos)
# Out:
# Valores nulos por columna:
# Estudiante          0
# Edad                0
# Género              0
# Nota_Matemáticas    0
# Nota_Ciencias       1
# Nota_Inglés         0
# dtype: int64

# %%
df[df.Nota_Ciencias.isnull()]
# Out:
#   Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 4         E5    20  Masculino              81.3            NaN         75.5

# %%
df.loc[df.index[4], 'Nota_Ciencias'] = df.Nota_Ciencias.median()

# %%
df.isnull().sum()
# Out:
# Estudiante          0
# Edad                0
# Género              0
# Nota_Matemáticas    0
# Nota_Ciencias       0
# Nota_Inglés         0
# dtype: int64

# %% [markdown]
# # <font color="red">1.12 Ejemplo con groupby
# Agrupación por género y cálculo del promedio de notas:

# %%
promedios_por_genero = df.groupby("Género")[["Nota_Matemáticas", "Nota_Ciencias", "Nota_Inglés"]].max()

print("Promedio de notas por género:")
print(promedios_por_genero)
# Out:
# Promedio de notas por género:
#            Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# Género
# Femenino               81.3           83.7         83.5
# Masculino              89.1          100.0         82.5

# %%
df[(df['Nota_Ciencias'] > 83) & (df['Nota_Ciencias'] < 94)]
# Out:
#    Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 3          E4    24  Masculino              69.7           89.4         75.2
# 7          E8    24  Masculino              89.1           89.3         68.6
# 8          E9    19  Masculino              49.7           84.4         62.5
# 15        E16    20   Femenino              58.4           83.7         74.6

# %% [markdown]
# ## <font color="blue">1.12.1 Visualización de promedios:

# %%
# Gráfico de barras apiladas para promedios por género
promedios_por_genero.plot(kind="bar", figsize=(8, 5), colormap="viridis")
plt.title("Promedio de Notas por Género")
plt.xlabel("Género")
plt.ylabel("Promedio")
plt.legend(title="Asignatura")
plt.show()

# %% [markdown]
# # <font color="red">1.13 Ejemplo con corr
# ## <font color="blue">1.13.1 Matriz de correlación entre variables numéricas:

# %%
# Seleccionar variables numéricas (int y float)
variables_numericas = df.select_dtypes(include=["int", "float"])

# Calcular la matriz de correlación
correlaciones = variables_numericas.corr()

# Imprimir la matriz de correlación
print("Matriz de correlación:")
print(correlaciones)
# Out:
# Matriz de correlación:
#                       Edad  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# Edad              1.000000          0.483522      -0.179197    -0.127124
# Nota_Matemáticas  0.483522          1.000000       0.138476     0.228811
# Nota_Ciencias    -0.179197          0.138476       1.000000     0.358039
# Nota_Inglés      -0.127124          0.228811       0.358039     1.000000

# %% [markdown]
# ## <font color="blue">1.13.2 Mapa de calor para visualizar correlaciones:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un dataset simulado (asegúrate de tener este paso antes si no lo tienes)
np.random.seed(42)
data = {
    "Estudiante": [f"E{i}" for i in range(1, 21)],
    "Edad": np.random.randint(18, 25, size=20),
    "Género": np.random.choice(["Femenino", "Masculino"], size=20),
    "Nota_Matemáticas": np.random.normal(70, 10, size=20).round(1),
    "Nota_Ciencias": np.random.normal(75, 12, size=20).round(1),
    "Nota_Inglés": np.random.normal(65, 15, size=20).round(1),
}
df = pd.DataFrame(data)

# Seleccionar solo las variables numéricas (int y float)
variables_numericas = df.select_dtypes(include=["int", "float"])

# Calcular la matriz de correlación
correlaciones = variables_numericas.corr()
# Create a mask to hide the lower triangle of the matrix
mask = np.triu(np.ones_like(correlaciones, dtype=bool))

# Crear el mapa de calor
sns.heatmap(correlaciones, annot=True, cmap="coolwarm", fmt=".2f", mask=mask)

# Añadir título al gráfico
plt.title("Mapa de Calor de Correlaciones")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # <font color="red">1.14 Ejemplo con apply para transformar datos
# Crear una columna de aprobación en matemáticas:

# %%
# Añadir columna indicando si aprobó matemáticas (nota >= 60)
df["Aprobado_Matemáticas"] = df["Nota_Matemáticas"].apply(lambda x: "Sí" if x >= 60 else "No")

df
# Out:
#    Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés  \
# 0          E1    24  Masculino              72.2           69.5         41.6
# 1          E2    21  Masculino              62.3           75.8         53.1
# 2          E3    22  Masculino              71.4           72.9         79.0
# 3          E4    24  Masculino              69.7           89.4         75.2
# 4          E5    20  Masculino              81.3           83.4         75.5
# 5          E6    22   Femenino              69.0           72.9         67.6
# 6          E7    22   Femenino              64.7           64.1         74.9
# 7          E8    24  Masculino              89.1           89.3         68.6
# 8          E9    19  Masculino              49.7           84.4         62.5
# 9         E10    20  Masculino              81.2          106.9         82.5
# 10        E11    24   Femenino              77.8           78.2         61.3
# ...

# %%
# Conteo de aprobaciones
aprobaciones = df["Aprobado_Matemáticas"].value_counts()

print("Conteo de aprobaciones en matemáticas:")
print(aprobaciones)
# Out:
# Conteo de aprobaciones en matemáticas:
# Aprobado_Matemáticas
# Sí    16
# No     4
# Name: count, dtype: int64

# %% [markdown]
# ## <font color="blue">1.14.1 Visualización:

# %%
# Gráfico circular para aprobaciones
aprobaciones.plot(kind="pie", autopct="%1.1f%%", colors=["lightgreen", "salmon"], startangle=90)
plt.title("Porcentaje de Aprobaciones en Matemáticas")
plt.ylabel("")  # Ocultar el label del eje Y
plt.show()

# %% [markdown]
# Estos ejemplos combinan el uso de Pandas para explorar y analizar datos, junto con gráficos de Seaborn y Matplotlib para visualizar patrones. Los comandos y visualizaciones cubren diferentes aspectos del análisis exploratorio, lo que los hace útiles para identificar características clave y tendencias en los datos.
